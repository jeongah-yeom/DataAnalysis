# %% [markdown]
# <a href="https://colab.research.google.com/github/jeongah-yeom/DataAnalysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
foo=42
FOO = 3.14
print(foo, FOO)
# Out:
# 42 3.14

# %%
1+1
# Out:
# 2

# %%
type(0.0001)
# Out:
# float

# %%
import pandas as pd
df = pd.DataFrame({'int':[1,2,3],
    'str':['R','S','T'],
    'bool':[True,False,True]})
df
# Out:
#    int str   bool
# 0    1   R   True
# 1    2   S  False
# 2    3   T   True

# %%
list =[6,1,3,6,10,5]
print(list[2])
# Out:
# 3

# %%
# prompt: df = pd.DataFrame({
#  'name': ["John", "Paul", "George", "Ringo"],
#  'birth': [1940, 1942, 1943, 1940],
#  'instrument': ["guitar", "bass", "guitar", "drums"]
#  }) df['birth']

df['birth']
# Out:
#      name  birth instrument
# 0    John   1940     guitar
# 1    Paul   1942       bass
# 2  George   1943     guitar
# 3   Ringo   1940      drums

# %%
df.iloc[0:3,0:2]
# Out:
#      name  birth
# 0    John   1940
# 1    Paul   1942
# 2  George   1943

# %%
df.iloc[0:2,0:2]
# Out:
#    name  birth
# 0  John   1940
# 1  Paul   1942

# %%
df.iloc[1:2,2:3]
# Out:
#   instrument
# 1       bass

# %%
df_1940 = df[df['birth'] == 1940]
print(df_1940)
# Out:
#     name  birth instrument
# 0   John   1940     guitar
# 3  Ringo   1940      drums

# %%
df_1941 = df[df['birth'] == 1941]
print(df_1940)
# Out:
#     name  birth instrument
# 0   John   1940     guitar
# 3  Ringo   1940      drums

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder

# %%
store_data_path = '/store_data (1).csv'

# %%
store_df = pd.read_csv(store_data_path, header=None)

store_df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
transactions= []
for i in range(len(store_df)):
  transaction = [str(item) for item in store_df.iloc[i] if pd.notna(item)]
  transactions.append(transaction)

  te = TransactionEncoder()

  te_ary = te.fit(transactions).transform(transactions)

  df= pd.DataFrame(te_ary, columns=te.columns_)
  df
